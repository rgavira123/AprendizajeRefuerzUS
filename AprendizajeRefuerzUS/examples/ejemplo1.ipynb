# %%
import sys
import os

ruta_src = os.path.join(os.path.dirname(os.getcwd()), 'src')
sys.path.append(os.path.abspath(ruta_src))

# %%
# Importamos los modulos necesarios

import problem as prob
import algorithms.Montecarlo as mc
import algorithms.sarsa as sarsa
import algorithms.Q_Learning as qlearning
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 import algorithms.Montecarlo as mc
#       5 import algorithms.sarsa as sarsa
# ----> 6 import algorithms.Q_Learning as qlearning
#
# File c:\Users\Daniel\OneDrive - UNIVERSIDAD DE SEVILLA\Documentos\Escritorio\PROYECTO_IA\robot-aprendizaje-refuerzo\AprendizajeRefuerzUS\src\algorithms\Q_Learning.py:2
#       1 import numpy as np
# ----> 2 import mdptoolbox.mdp as mdp
#       3 from .util import politica_procesable
#       7 class Q_Learning:
#
# ModuleNotFoundError: No module named 'mdptoolbox'

# %%
# Instanciamos el problema

problem = prob.Problem("../maps/map2.txt", 0.2)

# %%
# Visualizamos el mapa

problem.visualiza_mapa()

# %%
# Visualizamos la política

problem.visualiza_politica()
problem.transiciones
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Visualizamos la política
# ----> 3 problem.visualiza_politica()
#       4 problem.transiciones
#
# NameError: name 'problem' is not defined

# %%
transiciones = problem.transiciones
recompensas = problem.recompensas

# %%
modelo_qlearning = qlearning.Q_Learning(transiciones,recompensas)

modelo_qlearning.entrenar()

# %%
politica_qlearning = modelo_qlearning.obtener_politica()
# Out:
# ['E',
#  'O',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'O',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'NE',
#  'NE',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'NE',
#  'E',
#  'esperar',
#  'SO',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'NE',
#  'NE',
#  'E',
#  'E',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
#  'NO',
#  'SO',
#  'esperar',
#  'esperar',
#  'NE',
#  'esperar',
#  'esperar',
#  'esperar',
#  'esperar',
# ...

# %%
modelo_montecarlo = mc.MonteCarlo(transiciones,recompensas,max_iteraciones=2000)

modelo_montecarlo.entrenar_primera_visita()

# %%
politica_mc = modelo_montecarlo.obtener_politica()

# %%
problem.actualiza_politica(politica_mc)
problem.visualiza_politica()
